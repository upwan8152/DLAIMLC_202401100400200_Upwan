# %%
x=[75,65,80]
w=[4,3,5]
b=-1000
n=0.01
y=1

z=x[0]*w[0]+x[1]*w[1]+x[2]*w[2]+b
print(z)

#activation fn
if(z>=0):
  y_pred=1
else:
  y_pred=0
print(y_pred)
# Out:
# -105
# 0

# %%
error=y-y_pred
while(error!=0):
  wnew=[]
  for i in range(0,len(w)):
    w[i]=w[i]+(n*error*x[i])

  bnew=b+(n*error)

  z=x[0]*w[0]+x[1]*w[1]+x[2]*w[2]+b

  if(z>=0):
    y_pred=1
  else:
    y_pred=0

  error=y-y_pred
  print(error)
  print(y_pred)
# Out:
# 0
# 1
